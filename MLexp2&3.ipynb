# %% [markdown]
# <a href="https://colab.research.google.com/github/Moupriya-28/ML-lab/blob/main/MLexp2%263.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd

# Upload the file
from google.colab import files
uploaded = files.upload()  # Prompts you to upload your file

# Load the Excel file into a Pandas DataFrame
file_name = list(uploaded.keys())[0]  # Gets the uploaded file name
df = pd.read_excel(file_name)

# Display the first few rows of the DataFrame to understand its structure
print("DataFrame Head:")
print(df.head())

# Let the user specify the column names they want to extract
print("\nAvailable Columns in the DataFrame:")
print(df.columns.tolist())

# Input column names from the user
columns_to_extract = input("\nEnter the column names to extract, separated by commas: ").split(',')

# Strip any extra spaces from the column names
columns_to_extract = [col.strip() for col in columns_to_extract]

# Check if the specified columns exist in the DataFrame
missing_columns = [col for col in columns_to_extract if col not in df.columns]

if not missing_columns:
    # Extract the specified columns
    extracted_data = df[columns_to_extract]
    print("\nExtracted Data:")
    print(extracted_data)

    # Save the extracted data to a new Excel file (optional)
    extracted_data.to_excel('extracted_data.xlsx', index=False)
    print("\nExtracted data has been saved to 'extracted_data.xlsx'.")
else:
    print("\nThe following column(s) were not found in the DataFrame:")
    print(missing_columns)
# Out:
#      <input type="file" id="files-703dcd8a-c7ff-44dd-96c5-9e8ab57e0fcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-703dcd8a-c7ff-44dd-96c5-9e8ab57e0fcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
import pandas as pd

# Upload the file
from google.colab import files
uploaded = files.upload()  # Prompts you to upload your Excel file

# Load the Excel file into a Pandas DataFrame
file_name = list(uploaded.keys())[0]  # Gets the uploaded file name
df = pd.read_excel(file_name)

# Display the first few rows to understand the structure
print("DataFrame Head:")
df.head()

# Show available columns
print("\nAvailable Columns in the DataFrame:")
print(df.columns.tolist())

# Function for extracting a specific column
def extract_column():
    column_name = input("\nEnter the column name you want to extract: ").strip()
    if column_name in df.columns:
        print(f"\nData in column '{column_name}':")
        print(df[column_name])
    else:
        print(f"\nColumn '{column_name}' not found!")

# Function for extracting a specific row
def extract_row():
    index_value = input("\nEnter the index (row number) you want to extract: ").strip()
    try:
        index_value = int(index_value)  # Convert to integer
        if 0 <= index_value < len(df):
            print(f"\nData in row {index_value}:")
            print(df.iloc[index_value])
        else:
            print("\nInvalid row number!")
    except ValueError:
        print("\nPlease enter a valid integer for the row index!")

# Function to search within rows
def search_row():
    search_column = input("\nEnter the column name to search in: ").strip()
    if search_column in df.columns:
        search_value = input(f"Enter the value to search for in column '{search_column}': ").strip()
        result = df[df[search_column] == search_value]
        if not result.empty:
            print(f"\nRows matching '{search_value}' in column '{search_column}':")
            print(result)
        else:
            print(f"\nNo rows found with '{search_value}' in column '{search_column}'!")
    else:
        print(f"\nColumn '{search_column}' not found!")

# Menu for user interaction
while True:
    print("\nOptions:")
    print("1. Extract a specific column")
    print("2. Extract a specific row")
    print("3. Search for data within rows")
    print("4. Exit")

    choice = input("\nEnter your choice (1-4): ").strip()
    if choice == "1":
        extract_column()
    elif choice == "2":
        extract_row()
    elif choice == "3":
        search_row()
    elif choice == "4":
        print("\nExiting the program.")
        break
    else:
        print("\nInvalid choice! Please enter a number between 1 and 4.")
# Out:
#      <input type="file" id="files-a3b70c23-46d2-47f1-abf1-99df5b00d46c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3b70c23-46d2-47f1-abf1-99df5b00d46c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
